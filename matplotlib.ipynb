# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0, 6])
y = np.array([0,30])
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, '*')
plt.show()

# %%
x = np.arange(4)
y = np.arange(4)
plt.plot(x, y, 'x')
plt.show()

# %%
yy = np.array([5,3,9,7])
plt.plot(yy)
plt.show()

# %%
plt.plot(yy, marker = 'o')
plt.show()

# %%
plt.plot(y, 'o-.b')
plt.show()

# %%
plt.plot(y, 'o-.b', ms = 30)
plt.show()

# %%
plt.plot(y, 'o-.b', ms = 30, mec = 'y')
plt.show()

# %%
plt.plot(y, 'o-.b', ms = 30, mec = 'y', mfc = 'r')
plt.show()

# %%
plt.plot(yy, linestyle = 'dotted')
plt.show()

# %%
plt.plot(yy, linestyle = 'dashed', color = 'g', linewidth = '10.5')
plt.show()

# %%
plt.plot(yy)
plt.plot(y)
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.title('House price by size')
plt.xlabel('Size')
plt.ylabel('Price')
plt.show()

# %%
x3 = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y3 = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", loc = 'left') #title positioning with loc parameter
plt.xlabel("Average Pulse", fontdict = font1)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x3, y3)
plt.show()

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x3, y3)

plt.grid()

plt.show()

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x3, y3)

plt.grid(axis = 'y')

plt.show()

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x3, y3)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1) #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2) #the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
plt.scatter(x3, y3)
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
#You can specify the colormap with the keyword argument cmap
#with the value of the colormap, in this case 'viridis' which
#is one of the built-in colormaps available in Matplotlib.

plt.colorbar() #Include the actual colormap
plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral') #size of each point #alpha->blur

plt.colorbar()

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50", width = 0.3)
plt.show()

plt.barh(x, y)
plt.show()

plt.barh(x, y, height = 0.1)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

print(x)
plt.hist(x)
plt.show()
# Out:
# [159.45277205 178.44420343 182.77196273 176.64397308 183.35400691
#  177.85051254 159.63737454 159.26273428 176.59315629 168.86377853
#  165.25383901 168.54047373 172.39188058 163.45293798 168.99855464
#  168.89382083 169.78945999 163.93866288 172.42966952 178.96200415
#  182.76264187 184.78340004 166.4041643  182.59453847 156.50148899
#  182.02435989 163.37560785 170.01706795 168.71653241 174.54964225
#  159.76706731 185.68036855 184.96335351 186.22006458 171.50565915
#  159.592362   169.6250232  186.85886667 169.22362713 163.95461026
#  165.38189871 163.45861639 169.02253519 158.75058121 173.10838785
#  159.20633872 162.79305909 171.49720026 166.75783981 150.91379019
#  179.48835736 178.62736443 173.74925126 172.77234892 172.16835971
#  183.92614546 153.0397551  175.89921126 174.98854359 172.3310881
#  162.25714763 182.07758104 166.75273888 157.79910942 166.89970816
#  162.57017812 184.50248586 165.54254282 167.94337122 158.9858969
# ...

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]


plt.pie(y, labels = mylabels)
#By default the plotting of the first wedge starts from the x-axis and moves counterclockwise
plt.show()

# %%
plt.pie(y, labels = mylabels, startangle = 90) #Start the first wedge at 90 degrees
plt.show()

# %%
myexplode = [0.2, 0.1, 0.3, 0]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True, colors = mycolors)
plt.legend(title = "Four Fruits:")
plt.show()
